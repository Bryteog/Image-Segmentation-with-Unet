# %%
import os
import pandas as pd
import numpy as np
import imageio
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers
from Constants import *
import outputs
# %matplotlib inline

# %%
image_list_dir = os.listdir(image_dir)
mask_list_dir = os.listdir(mask_dir)
image_list = [image_dir + i for i in image_list_dir]
mask_list = [mask_dir + i for i in mask_list_dir]
print(image_list,'\n',mask_list)
# Out:
# ['../data/image/000026.png', '../data/image/000027.png', '../data/image/000028.png', '../data/image/000029.png', '../data/image/000032.png', '../data/image/000033.png', '../data/image/000034.png', '../data/image/000043.png', '../data/image/000044.png', '../data/image/000045.png', '../data/image/000073.png', '../data/image/000084.png', '../data/image/000085.png', '../data/image/000156.png', '../data/image/000688.png', '../data/image/000689.png', '../data/image/000690.png', '../data/image/000691.png', '../data/image/000693.png', '../data/image/000694.png', '../data/image/000695.png', '../data/image/000728.png', '../data/image/001887.png', '../data/image/001888.png', '../data/image/001889.png', '../data/image/001890.png', '../data/image/001891.png', '../data/image/001892.png', '../data/image/001893.png', '../data/image/001894.png', '../data/image/001896.png', '../data/image/001898.png', '../data/image/001902.png', '../data/image/001903.png', '../data/image/001904.png', '../data/image/001905.png', '../data/image/001906.png', '../data/image/001914.png', '../data/image/001915.png', '../data/image/001918.png', '../data/image/001926.png', '../data/image/001932.png', '../data/image/001935.png', '../data/image/001936.png', '../data/image/001945.png', '../data/image/001948.png', '../data/image/001957.png', '../data/image/001960.png', '../data/image/001966.png', '../data/image/002106.png', '../data/image/002107.png', '../data/image/002108.png', '../data/image/002109.png', '../data/image/002110.png', '../data/image/002111.png', '../data/image/002112.png', '../data/image/002113.png', '../data/image/002114.png', '../data/image/002115.png', '../data/image/002116.png', '../data/image/002121.png', '../data/image/002122.png', '../data/image/002123.png', '../data/image/002124.png', '../data/image/002125.png', '../data/image/002126.png', '../data/image/002128.png', '../data/image/002132.png', '../data/image/002134.png', '../data/image/002137.png', '../data/image/002141.png', '../data/image/002155.png', '../data/image/002158.png', '../data/image/002159.png', '../data/image/002161.png', '../data/image/002162.png', '../data/image/002165.png', '../data/image/002169.png', '../data/image/002173.png', '../data/image/002174.png', '../data/image/002177.png', '../data/image/002270.png', '../data/image/002271.png', '../data/image/002272.png', '../data/image/002273.png', '../data/image/002274.png', '../data/image/002275.png', '../data/image/002276.png', '../data/image/002277.png', '../data/image/002278.png', '../data/image/002279.png', '../data/image/002280.png', '../data/image/002281.png', '../data/image/002285.png', '../data/image/002286.png', '../data/image/002287.png', '../data/image/002288.png', '../data/image/002289.png', '../data/image/002292.png', '../data/image/002293.png', '../data/image/002294.png', '../data/image/002295.png', '../data/image/002296.png', '../data/image/002297.png', '../data/image/002298.png', '../data/image/002300.png', '../data/image/002301.png', '../data/image/002303.png', '../data/image/002304.png', '../data/image/002312.png', '../data/image/002314.png', '../data/image/002317.png', '../data/image/002319.png', '../data/image/002320.png', '../data/image/002321.png', '../data/image/002324.png', '../data/image/002325.png', '../data/image/002712.png', '../data/image/002713.png', '../data/image/002714.png', '../data/image/002715.png', '../data/image/002716.png', '../data/image/002717.png', '../data/image/002718.png', '../data/image/002719.png', '../data/image/002720.png', '../data/image/002721.png', '../data/image/002723.png', '../data/image/002724.png', '../data/image/002725.png', '../data/image/002730.png', '../data/image/002731.png', '../data/image/002732.png', '../data/image/002733.png', '../data/image/002734.png', '../data/image/002735.png', '../data/image/002737.png', '../data/image/002738.png', '../data/image/002739.png', '../data/image/002740.png', '../data/image/002741.png', '../data/image/002744.png', '../data/image/002747.p ...
#  ['../data/mask/000026.png', '../data/mask/000027.png', '../data/mask/000028.png', '../data/mask/000029.png', '../data/mask/000032.png', '../data/mask/000033.png', '../data/mask/000034.png', '../data/mask/000043.png', '../data/mask/000044.png', '../data/mask/000045.png', '../data/mask/000073.png', '../data/mask/000084.png', '../data/mask/000085.png', '../data/mask/000156.png', '../data/mask/000688.png', '../data/mask/000689.png', '../data/mask/000690.png', '../data/mask/000691.png', '../data/mask/000693.png', '../data/mask/000694.png', '../data/mask/000695.png', '../data/mask/000728.png', '../data/mask/001887.png', '../data/mask/001888.png', '../data/mask/001889.png', '../data/mask/001890.png', '../data/mask/001891.png', '../data/mask/001892.png', '../data/mask/001893.png', '../data/mask/001894.png', '../data/mask/001896.png', '../data/mask/001898.png', '../data/mask/001902.png', '../data/mask/001903.png', '../data/mask/001904.png', '../data/mask/001905.png', '../data/mask/001906.png', '../data/mask/001914.png', '../data/mask/001915.png', '../data/mask/001918.png', '../data/mask/001926.png', '../data/mask/001932.png', '../data/mask/001935.png', '../data/mask/001936.png', '../data/mask/001945.png', '../data/mask/001948.png', '../data/mask/001957.png', '../data/mask/001960.png', '../data/mask/001966.png', '../data/mask/002106.png', '../data/mask/002107.png', '../data/mask/002108.png', '../data/mask/002109.png', '../data/mask/002110.png', '../data/mask/002111.png', '../data/mask/002112.png', '../data/mask/002113.png', '../data/mask/002114.png', '../data/mask/002115.png', '../data/mask/002116.png', '../data/mask/002121.png', '../data/mask/002122.png', '../data/mask/002123.png', '../data/mask/002124.png', '../data/mask/002125.png', '../data/mask/002126.png', '../data/mask/002128.png', '../data/mask/002132.png', '../data/mask/002134.png', '../data/mask/002137.png', '../data/mask/002141.png', '../data/mask/002155.png', '../data/mask/002158.png', '../data/mask/002159.png', '../data/mask/002161.png', '../data/mask/002162.png', '../data/mask/002165.png', '../data/mask/002169.png', '../data/mask/002173.png', '../data/mask/002174.png', '../data/mask/002177.png', '../data/mask/002270.png', '../data/mask/002271.png', '../data/mask/002272.png', '../data/mask/002273.png', '../data/mask/002274.png', '../data/mask/002275.png', '../data/mask/002276.png', '../data/mask/002277.png', '../data/mask/002278.png', '../data/mask/002279.png', '../data/mask/002280.png', '../data/mask/002281.png', '../data/mask/002285.png', '../data/mask/002286.png', '../data/mask/002287.png', '../data/mask/002288.png', '../data/mask/002289.png', '../data/mask/002292.png', '../data/mask/002293.png', '../data/mask/002294.png', '../data/mask/002295.png', '../data/mask/002296.png', '../data/mask/002297.png', '../data/mask/002298.png', '../data/mask/002300.png', '../data/mask/002301.png', '../data/mask/002303.png', '../data/mask/002304.png', '../data/mask/002312.png', '../data/mask/002314.png', '../data/mask/002317.png', '../data/mask/002319.png', '../data/mask/002320.png', '../data/mask/002321.png', '../data/mask/002324.png', '../data/mask/002325.png', '../data/mask/002712.png', '../data/mask/002713.png', '../data/mask/002714.png', '../data/mask/002715.png', '../data/mask/002716.png', '../data/mask/002717.png', '../data/mask/002718.png', '../data/mask/002719.png', '../data/mask/002720.png', '../data/mask/002721.png', '../data/mask/002723.png', '../data/mask/002724.png', '../data/mask/002725.png', '../data/mask/002730.png', '../data/mask/002731.png', '../data/mask/002732.png', '../data/mask/002733.png', '../data/mask/002734.png', '../data/mask/002735.png', '../data/mask/002737.png', '../data/mask/002738.png', '../data/mask/002739.png', '../data/mask/002740.png', '../data/mask/002741.png', '../data/mask/002744.png', '../data/mask/002747.png', '../data/mask/002755.png', '../data/mask/002756.png', '../data/mask/002758.png', '../data/mask/002759.png', '../data/mask/002761.png', '. ...

# %%
NUM_SAMPLES = 2
image = imageio.v2.imread(image_list[NUM_SAMPLES])
mask = imageio.v2.imread(mask_list[NUM_SAMPLES])

figure, array = plt.subplots(1, 2, figsize = (14, 10))
array[0].imshow(image)
array[0].set_title("Image")
array[1].imshow(mask[:, :, 0])
array[1].set_title("Segmented image")
# Out:
# Text(0.5, 1.0, 'Segmented image')

# %%
image_dataset = tf.data.Dataset.list_files(image_list, shuffle = False)
mask_dataset = tf.data.Dataset.list_files(mask_list, shuffle = False)

# %%
image_files = tf.constant(image_list)
mask_files = tf.constant(mask_list)

dataset = tf.data.Dataset.from_tensor_slices((image_files, mask_files))

# %%
for image, mask in dataset.take(1):
    print(image)
    print(mask)
# Out:
# tf.Tensor(b'../data/image/000026.png', shape=(), dtype=string)
# tf.Tensor(b'../data/mask/000026.png', shape=(), dtype=string)

# %%
def preprocessing_path(image_path, mask_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels = 3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels = 3)
    mask = tf.math.reduce_max(mask, axis =- 1, keepdims = True)
    
    return image, mask


def image_preprocessing(image, mask):
    image = tf.image.resize(image, (96, 128), method = 'nearest')
    mask = tf.image.resize(mask, (96, 128), method = 'nearest')
    #image = image / 255.
    
    return image, mask

image_dataset = dataset.map(preprocessing_path)
processed_images = image_dataset.map(image_preprocessing)

# %%
# Unet Model

def conv_block(inputs = None, NUM_FILTERS = 32, dropout_prob = 0, max_pooling2D = True):
    
    conv = layers.Conv2D(NUM_FILTERS, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv = layers.Conv2D(NUM_FILTERS, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv)
    
    if dropout_prob > 0:
        conv = layers.Dropout(dropout_prob)(conv)
        
    if max_pooling2D:
        next_layer = layers.MaxPooling2D(pool_size = (2, 2))(conv)
    else:
        next_layer = conv
        
    skip_connection = conv
    
    return next_layer, skip_connection

# %%
INPUT_SHAPE = (96, 128, 3)
inputs = layers.Input(INPUT_SHAPE)

conv_block1 = conv_block(inputs, NUM_FILTERS * 1)
model_1 = keras.Model(inputs = inputs, outputs = conv_block1)

output_1 = [['InputLayer', [(None, 96, 128, 3)], 0],
           ['Conv2D', (None, 96, 128, 32), 896, 'same', 'relu', 'HeNormal'],
           ['Conv2D', (None, 96, 128, 32), 9248, 'same', 'relu', 'HeNormal'],
           ['MaxPooling2D', (None, 48, 64, 32), 0, (2, 2)]]


conv_block1 = conv_block(inputs, NUM_FILTERS * 32, dropout_prob = 0.1, max_pooling2D = True)
model_2 = keras.Model(inputs = inputs, outputs = conv_block1)
output_2 = [['InputLayer', [(None, 96, 128, 3)], 0],
           ['Conv2D', (None, 96, 128, 1024), 28672, 'same', 'relu', 'HeNormal'],
           ['Conv2D', (None, 96, 128, 1024), 9438208, 'same', 'relu', 'HeNormal'],
           ['Dropout', (None, 96, 128, 1024), 0, 0.1],
           ['MaxPooling2D', (None, 48, 64, 1024), 0, (2, 2)]]

# %%
def upsampling_block(expansive_input, contractive_input, NUM_FILTERS):
    
    upsample = layers.Conv2DTranspose(NUM_FILTERS, 3, strides = 2, padding = 'same')(expansive_input)
    merge = layers.concatenate([upsample, contractive_input], axis = 3)
    
    conv = layers.Conv2D(NUM_FILTERS, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge)
    conv = layers.Conv2D(NUM_FILTERS, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv)
    
    return conv

# %%
INPUT_SHAPE_1 = (12, 16, 256)
INPUT_SHAPE_2 = (24, 32, 128)

expansive_inputs = layers.Input(INPUT_SHAPE_1)
contractive_inputs = layers.Input(INPUT_SHAPE_2)

conv_block1 = upsampling_block(expansive_inputs, contractive_inputs, NUM_FILTERS * 1)
model_1 = keras.Model(inputs = [expansive_inputs, contractive_inputs], outputs = conv_block1)

output_1 = [['InputLayer', [(None, 12, 16, 256)], 0],
           ['Conv2DTranspose', (None, 24, 32, 32), 73760],
           ['InputLayer', (None, 24, 32, 128), 0],
           ['Concatenate', (None, 24, 32, 160), 0],
           ['Conv2D', (None, 24, 32, 32), 46112, 'same', 'relu', 'HeNormal'],
           ['Conv2D', (None, 24, 32, 32), 9248, 'same', 'relu', 'HeNormal']]

# %%
def summary(model):
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    result = []
    for layer in model.layers:
        descriptors = [layer.__class__.__name__, layer.output_shape, layer.count_params()]
        if (type(layer) == layers.Conv2D):
            descriptors.append(layer.padding)
            descriptors.append(layer.activation.__name__)
            descriptors.append(layer.kernel_initializer.__class__.__name__)
        if (type(layer) == layers.MaxPooling2D):
            descriptors.append(layer.pool_size)
        if (type(layer) == layers.Dropout):
            descriptors.append(layer.rate)
        result.append(descriptors)
    return result

# %%
def Unet_model(input_size = (96, 128, 3), NUM_FILTERS = 32, NUM_CLASSES = 23):
    
    # Encoding block
    inputs = layers.Input(input_size)
    conv_block1 = conv_block(inputs, NUM_FILTERS)
    conv_block2 = conv_block(conv_block1[0], NUM_FILTERS * 2)
    conv_block3 = conv_block(conv_block2[0], NUM_FILTERS * 4)
    conv_block4 = conv_block(conv_block3[0], NUM_FILTERS * 8, dropout_prob = 0.3)
    conv_block5 = conv_block(conv_block4[0], NUM_FILTERS * 16, dropout_prob = 0.3, max_pooling2D = False)
    
    # Decoding block
    upsampling_block1 = upsampling_block(conv_block5[0], conv_block4[1], NUM_FILTERS * 8)
    upsampling_block2 = upsampling_block(upsampling_block1, conv_block3[1], NUM_FILTERS * 4)
    upsampling_block3 = upsampling_block(upsampling_block2, conv_block2[1], NUM_FILTERS * 2)
    upsampling_block4 = upsampling_block(upsampling_block3, conv_block1[1], NUM_FILTERS)
    
    conv_block6 = layers.Conv2D(NUM_FILTERS, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(upsampling_block4)
    conv_block7 = layers.Conv2D(NUM_CLASSES, 1, padding = 'same')(conv_block6)
    
    model = keras.Model(inputs = inputs, outputs = conv_block7)
    
    return model

# %%
unet_model = Unet_model((IMAGE_HEIGHT, IMAGE_WIDTH, NUM_CHANNELS))
unet_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 96, 128, 3)]         0         []
#
#  conv2d_6 (Conv2D)           (None, 96, 128, 32)          896       ['input_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 96, 128, 32)          9248      ['conv2d_6[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 64, 32)           0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 48, 64, 64)           18496     ['max_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 48, 64, 64)           36928     ['conv2d_8[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 24, 32, 64)           0         ['conv2d_9[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 24, 32, 128)          73856     ['max_pooling2d_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 24, 32, 128)          147584    ['conv2d_10[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 12, 16, 128)          0         ['conv2d_11[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 12, 16, 256)          295168    ['max_pooling2d_4[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 12, 16, 256)          590080    ['conv2d_12[0][0]']
#
#  dropout_1 (Dropout)         (None, 12, 16, 256)          0         ['conv2d_13[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 6, 8, 256)            0         ['dropout_1[0][0]']
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 6, 8, 512)            1180160   ['max_pooling2d_5[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 6, 8, 512)            2359808   ['conv2d_14[0][0]']
#
#  dropout_2 (Dropout)         (None, 6, 8, 512)            0         ['conv2d_15[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 12, 16, 256)          1179904   ['dropout_2[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 12, 16, 512)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'dropout_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 12, 16, 256)          1179904   ['concatenate_1[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 12, 16, 256)          590080    ['conv2d_16[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 24, 32, 128)          295040    ['conv2d_17[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 24, 32, 256)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_11[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 24, 32, 128)          295040    ['concatenate_2[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 24, 32, 128)          147584    ['conv2d_18[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 48, 64, 64)           73792     ['conv2d_19[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 48, 64, 128)          0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_9[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 48, 64, 64)           73792     ['concatenate_3[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 48, 64, 64)           36928     ['conv2d_20[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 96, 128, 32)          18464     ['conv2d_21[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 96, 128, 64)          0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'conv2d_7[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 96, 128, 32)          18464     ['concatenate_4[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 96, 128, 32)          9248      ['conv2d_22[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 96, 128, 32)          9248      ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 96, 128, 23)          759       ['conv2d_24[0][0]']
#
# ==================================================================================================
# Total params: 8640471 (32.96 MB)
# Trainable params: 8640471 (32.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
unet_model.compile(optimizer = 'adam', 
                   loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
                   metrics = ['accuracy'])

# %%
def display_image(display_list):
    
    plt.figure(figsize = (12, 12))
    title = ["Input Image", "True Mask", "Predicted Mask"]
    
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i + 1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis("off")
    plt.show()

# %%
# display sample image, its processed version and their masks

for image, mask in image_dataset.take(1):
    sample_image, sample_mask = image, mask
    print(mask.shape)
display_image([sample_image, sample_mask])
# Out:
# (480, 640, 1)

# %%
for image, mask in processed_images.take(1):
    sample_image, sample_mask = image, mask
    print(mask.shape)
display_image([sample_image, sample_mask])
# Out:
# (96, 128, 1)

# %%
processed_images.batch(BATCH_SIZE)
train_set = processed_images.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
history = unet_model.fit(train_set,
                         epochs = EPOCH_NUM)
# Out:
# Epoch 1/40
# 34/34 [==============================] - 267s 7s/step - loss: 1.8034 - accuracy: 0.4573
# Epoch 2/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.7789 - accuracy: 0.7976
# Epoch 3/40
# 34/34 [==============================] - 251s 7s/step - loss: 0.5632 - accuracy: 0.8408
# Epoch 4/40
# 34/34 [==============================] - 299s 9s/step - loss: 0.5232 - accuracy: 0.8539
# Epoch 5/40
# 34/34 [==============================] - 243s 7s/step - loss: 0.4282 - accuracy: 0.8715
# Epoch 6/40
# 34/34 [==============================] - 242s 7s/step - loss: 0.3727 - accuracy: 0.8858
# Epoch 7/40
# 34/34 [==============================] - 251s 7s/step - loss: 0.3254 - accuracy: 0.9007
# Epoch 8/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.2997 - accuracy: 0.9096
# Epoch 9/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.2930 - accuracy: 0.9126
# Epoch 10/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.2489 - accuracy: 0.9261
# Epoch 11/40
# 34/34 [==============================] - 240s 7s/step - loss: 0.2130 - accuracy: 0.9362
# Epoch 12/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.2074 - accuracy: 0.9376
# Epoch 13/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.2101 - accuracy: 0.9368
# Epoch 14/40
# 34/34 [==============================] - 249s 7s/step - loss: 0.1739 - accuracy: 0.9474
# Epoch 15/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.1627 - accuracy: 0.9511
# Epoch 16/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.1538 - accuracy: 0.9537
# Epoch 17/40
# 34/34 [==============================] - 240s 7s/step - loss: 0.1494 - accuracy: 0.9552
# Epoch 18/40
# 34/34 [==============================] - 9633s 292s/step - loss: 0.1404 - accuracy: 0.9579
# Epoch 19/40
# 34/34 [==============================] - 249s 7s/step - loss: 0.1326 - accuracy: 0.9601
# Epoch 20/40
# 34/34 [==============================] - 240s 7s/step - loss: 0.1250 - accuracy: 0.9623
# Epoch 21/40
# 34/34 [==============================] - 238s 7s/step - loss: 0.1231 - accuracy: 0.9626
# Epoch 22/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.1115 - accuracy: 0.9664
# Epoch 23/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.1479 - accuracy: 0.9556
# Epoch 24/40
# 34/34 [==============================] - 238s 7s/step - loss: 0.1117 - accuracy: 0.9665
# Epoch 25/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.1006 - accuracy: 0.9699
# Epoch 26/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.1059 - accuracy: 0.9678
# Epoch 27/40
# 34/34 [==============================] - 238s 7s/step - loss: 0.1064 - accuracy: 0.9678
# Epoch 28/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0952 - accuracy: 0.9710
# Epoch 29/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0924 - accuracy: 0.9720
# Epoch 30/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0876 - accuracy: 0.9729
# Epoch 31/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0859 - accuracy: 0.9736
# Epoch 32/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0828 - accuracy: 0.9742
# Epoch 33/40
# 34/34 [==============================] - 241s 7s/step - loss: 0.0832 - accuracy: 0.9743
# Epoch 34/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0787 - accuracy: 0.9757
# Epoch 35/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0817 - accuracy: 0.9745
# Epoch 36/40
# 34/34 [==============================] - 244s 7s/step - loss: 0.0775 - accuracy: 0.9759
# Epoch 37/40
# 34/34 [==============================] - 238s 7s/step - loss: 0.0736 - accuracy: 0.9770
# Epoch 38/40
# 34/34 [==============================] - 238s 7s/step - loss: 0.0724 - accuracy: 0.9775
# Epoch 39/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0743 - accuracy: 0.9765
# Epoch 40/40
# 34/34 [==============================] - 239s 7s/step - loss: 0.0717 - accuracy: 0.9775

# %%
plt.plot(history.history['accuracy'])
plt.title("Accuracy")
plt.show()

# %%
plt.plot(history.history['loss'])
plt.legend(loc = 'upper right')
plt.title("Loss")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def make_mask(predicted_mask):
    predicted_mask = tf.argmax(predicted_mask, axis =- 1)
    predicted_mask = predicted_mask[..., tf.newaxis]
    
    return predicted_mask[0]

# %%
def display_prediction(dataset = None, num = 1):
    
    if dataset:
        for image, mask in dataset.take(num):
            predicted_mask = unet_model.predict(image)
            display_image([image[0], mask[0], make_mask(predicted_mask)])
    else:
        display_image([sample_image,
                 sample_mask,
                 make_mask(unet_model.predict(sample_image[tf.newaxis, ...]))])

# %%
display_prediction(train_set, 10)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step

# %%
unet_model.save("../segmentation_2/")
# Out:
# INFO:tensorflow:Assets written to: ../segmentation_2/assets
# INFO:tensorflow:Assets written to: ../segmentation_2/assets
